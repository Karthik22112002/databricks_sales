# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

schema = StructType([
    StructField("order_id", StringType(), True),
    StructField("order_date", StringType(), True),
    StructField("customer_id", StringType(), True),
    StructField("customer_name", StringType(), True),
    StructField("city", StringType(), True),
    StructField("state", StringType(), True),
    StructField("product_id", StringType(), True),
    StructField("product_name", StringType(), True),
    StructField("category", StringType(), True),
    StructField("quantity", IntegerType(), True),
    StructField("unit_price", DoubleType(), True),
    StructField("discount_pct", DoubleType(), True),
    StructField("gross_amount", DoubleType(), True),
    StructField("discount_amount", DoubleType(), True),
    StructField("net_amount", DoubleType(), True),
    StructField("payment_method", StringType(), True),
    StructField("order_status", StringType(), True)
])

df = spark.read.format("csv").option("header", True).schema(schema).load("/Workspace/Users/alihi122007@gmail.com/databricks_sales_capstone/data/sales_source_1500.csv")
df.write.mode("overwrite").saveAsTable("workspace.ibm.capstone_bronze_sales")

# %%
from pyspark.sql.functions import *

source_path = "/Workspace/Users/alihi122007@gmail.com/databricks_sales_capstone/data/sales_source_1500.csv"

df = (
    spark.read
    .format("csv")
    .option("header", "true")
    .option("inferSchema", "false")
    .load(source_path)
)

df.write \
    .mode("overwrite") \
    .saveAsTable("workspace.ibm.capstone_bronze_sales1")

print("Bronze ingestion completed")
print(f"Bronze record count: {df.count()}")

display(df)
df.printSchema()
